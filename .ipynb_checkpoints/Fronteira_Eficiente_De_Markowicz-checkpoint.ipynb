# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in c:\users\marce\anaconda3\lib\site-packages (0.1.74)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: requests>=2.26 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\marce\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marce\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\marce\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)

# %%
#Puxar as ações da B3, sempre necessário colcoar o ".sa" no final do papel. Também verificar se o Data Frame está correto

acoes = ['LIGT3.SA', 'BBAS3.SA', 'PETR4.SA', 'MGLU3.SA', 'VALE3.SA']
carteira = pd.DataFrame()
for i in acoes:
  carteira[i] = yf.download(i, period='1y')['Adj Close']
carteira
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              LIGT3.SA   BBAS3.SA   PETR4.SA   MGLU3.SA   VALE3.SA
# Date
# 2021-08-23  14.552797  27.581085  16.065605  18.129999  79.785645
# 2021-08-24  15.048916  28.482368  16.398573  19.240000  82.696747
# 2021-08-25  15.029460  28.389288  16.487759  19.549999  82.522583
# 2021-08-26  15.185104  27.989042  16.345062  18.799999  81.469284
# 2021-08-27  14.805720  28.417213  16.939642  19.030001  83.509537
# ...               ...        ...        ...        ...        ...
# 2022-08-16   6.460000  42.988476  32.009998   4.150000  69.820000
# 2022-08-17   6.510000  42.600388  32.759998   4.020000  68.230003
# 2022-08-18   6.390000  41.615231  33.419998   4.030000  67.720001
# 2022-08-19   6.120000  40.849003  31.730000   3.780000  66.959999
# 2022-08-22   5.980000  41.266949  32.410000   3.820000  65.980003
#
# [250 rows x 5 columns]

# %%
n = len(carteira)
rendimento = [1]
for i in range(n):
  ult_rend = rendimento[-1]
rend_atual = 1.013 * ult_rend

rendimento.append(ult_rend)

# %%
sns.set()
carteira_normalizada = carteira/carteira.iloc[0]
carteira_normalizada.plot(figsize=(21,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
retorno = carteira.pct_change()
retorno
# Out:
#             LIGT3.SA  BBAS3.SA  PETR4.SA  MGLU3.SA  VALE3.SA
# Date
# 2021-08-23       NaN       NaN       NaN       NaN       NaN
# 2021-08-24  0.034091  0.032678  0.020726  0.061225  0.036487
# 2021-08-25 -0.001293 -0.003268  0.005439  0.016112 -0.002106
# 2021-08-26  0.010356 -0.014098 -0.008655 -0.038363 -0.012764
# 2021-08-27 -0.024984  0.015298  0.036377  0.012234  0.025043
# ...              ...       ...       ...       ...       ...
# 2022-08-16 -0.012232  0.004885  0.009142  0.027228  0.022255
# 2022-08-17  0.007740 -0.009028  0.023430 -0.031325 -0.022773
# 2022-08-18 -0.018433 -0.023126  0.020147  0.002488 -0.007475
# 2022-08-19 -0.042254 -0.018412 -0.050568 -0.062035 -0.011223
# 2022-08-22 -0.022876  0.010231  0.021431  0.010582 -0.014636
#
# [250 rows x 5 columns]

# %%
#A média diária de retorno anual é multiplicada pela quantidade de DIAS ÚTEIS para ativos da B3

retorno_anual = retorno.mean() * 264
retorno_anual
# Out:
# LIGT3.SA   -0.762465
# BBAS3.SA    0.473213
# PETR4.SA    0.817634
# MGLU3.SA   -1.306960
# VALE3.SA   -0.128017
# dtype: float64

# %%
cov = retorno.cov() * 264
cov
# Out:
#           LIGT3.SA  BBAS3.SA  PETR4.SA  MGLU3.SA  VALE3.SA
# LIGT3.SA  0.357401  0.064390  0.056976  0.189455  0.018387
# BBAS3.SA  0.064390  0.092026  0.056413  0.062302  0.022728
# PETR4.SA  0.056976  0.056413  0.145975  0.050079  0.045522
# MGLU3.SA  0.189455  0.062302  0.050079  0.682871  0.032142
# VALE3.SA  0.018387  0.022728  0.045522  0.032142  0.147354

# %%
num_acoes = len(acoes)
num_carteiras = 10000

lista_retornos = []
lista_volatilidade = []
lista_pesos = []
lista_sharpe_ratio = []

# %%
for carteira in range(num_carteiras):
  peso = np.random.random(num_acoes)
  peso /= np.sum(peso)
  lista_pesos.append(peso)
  retorno_esperado = np.dot(peso, retorno_anual)
  lista_retornos.append(retorno_esperado)
  volatilidade = np.sqrt(np.dot(peso.T, np.dot(cov, peso)))
  lista_volatilidade.append(volatilidade)
  sharpe_ratio = retorno_esperado/volatilidade
  lista_sharpe_ratio.append(sharpe_ratio)

# %%
dic_carteiras = {'Retorno': lista_retornos, 'Volatilidade': lista_volatilidade, 'Sharpe Ratio': lista_sharpe_ratio}
for contar,acao in enumerate(acoes):
  dic_carteiras[acao+' Peso'] = [Peso[contar] for Peso in lista_pesos]
portfolios = pd.DataFrame(dic_carteiras)
colunas = ['Retorno', 'Volatilidade', 'Sharpe Ratio'] + [acao+' Peso' for acao in acoes]

portfolios = portfolios[colunas]
portfolios
# Out:
#        Retorno  Volatilidade  Sharpe Ratio  LIGT3.SA Peso  BBAS3.SA Peso  \
# 0    -0.253082      0.331554     -0.763319       0.242933       0.294554
# 1     0.115006      0.290208      0.396287       0.253183       0.290291
# 2    -0.180978      0.354338     -0.510749       0.007385       0.001888
# 3    -0.399841      0.368458     -1.085174       0.185233       0.061645
# 4    -0.484672      0.415388     -1.166792       0.399643       0.051681
# ...        ...           ...           ...            ...            ...
# 9995 -0.186216      0.339041     -0.549241       0.201349       0.233264
# 9996 -0.037445      0.340729     -0.109896       0.176799       0.138080
# 9997 -0.284977      0.344201     -0.827939       0.228770       0.125727
# 9998 -0.050274      0.295592     -0.170080       0.260942       0.060317
# 9999 -0.600192      0.402698     -1.490428       0.291880       0.012305
#
#       PETR4.SA Peso  MGLU3.SA Peso  VALE3.SA Peso
# 0          0.086380       0.194849       0.181284
# 1          0.276651       0.027561       0.152315
# 2          0.321475       0.299771       0.369481
# 3          0.166557       0.295919       0.290647
# 4          0.180761       0.258800       0.109116
# ...             ...            ...            ...
# 9995       0.207561       0.226456       0.131369
# 9996       0.393182       0.213826       0.078114
# 9997       0.193033       0.228977       0.223493
# 9998       0.236056       0.013736       0.428948
# 9999       0.072297       0.307697       0.315820
#
# [10000 rows x 8 columns]

# %%
plt.style.use('seaborn-dark')
portfolios.plot.scatter(x='Volatilidade', y='Retorno', c='Sharpe Ratio', edgecolors='black', figsize=(21,9), grid=True)
plt.xlabel('Volatilidade', fontsize=16)
plt.ylabel('Retorno Esperado', fontsize=16)
plt.title('Fronteira Eficiente de Markowitz', fontsize=22)
plt.savefig('Fronteira.png', dpi = 500)

# %%
sns.scatterplot(x = 'Volatilidade', y = 'Retorno', hue = 'Sharpe Ratio', data = portfolios, legend=None)
sns.set_xticklabels('Volatilidade', fontsize = 16)
sns.set_yticklabels('Retorno Esperado', fontsize = 16)
sns.set_title('Fronteira Eficiente de Markowitz', fontsize = 22)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 sns.scatterplot(x = 'Volatilidade', y = 'Retorno', hue = 'Sharpe Ratio', data = portfolios, legend=None)
# ----> 2 sns.set_xticklabels('Volatilidade', fontsize = 16)
#       3 sns.set_yticklabels('Retorno Esperado', fontsize = 16)
#       4 sns.set_title('Fronteira Eficiente de Markowitz', fontsize = 22)
#
# AttributeError: module 'seaborn' has no attribute 'set_xticklabels'

# %%
menor_volatilidade = portfolios['Volatilidade'].min()
carteira_min_variancia = portfolios.loc[portfolios['Volatilidade'] == menor_volatilidade]
carteira_min_variancia.T

# %%
maior_sharpe = portfolios['Sharpe Ratio'].max()
carteira_maior_sharpe = portfolios.loc[portfolios['Sharpe Ratio'] == maior_sharpe]
carteira_maior_sharpe.T
# Out:
#                    4320
# Retorno        0.591448
# Volatilidade   0.294138
# Sharpe Ratio   2.010780
# LIGT3.SA Peso  0.014812
# BBAS3.SA Peso  0.362790
# PETR4.SA Peso  0.551195
# MGLU3.SA Peso  0.008903
# VALE3.SA Peso  0.062299

# %%
maiores_rendimentos = portfolios.nlargest(1000, ['Retorno'])
print(maiores_rendimentos)
# Out:
#        Retorno  Volatilidade  Sharpe Ratio  LIGT3.SA Peso  BBAS3.SA Peso  \
# 4320  0.591448      0.294138      2.010780       0.014812       0.362790
# 2379  0.561671      0.297711      1.886632       0.049813       0.317046
# 9074  0.553266      0.298210      1.855290       0.064927       0.305120
# 3050  0.546987      0.300441      1.820616       0.028550       0.352358
# 809   0.539073      0.299776      1.798252       0.036919       0.286016
# ...        ...           ...           ...            ...            ...
# 1028  0.097934      0.285812      0.342653       0.200784       0.614789
# 2572  0.097767      0.311916      0.313442       0.320409       0.211540
# 8276  0.097551      0.290129      0.336234       0.052231       0.196702
# 2201  0.097374      0.268173      0.363103       0.177695       0.275994
# 9918  0.097342      0.300018      0.324453       0.267849       0.136975
#
#       PETR4.SA Peso  MGLU3.SA Peso  VALE3.SA Peso
# 4320       0.551195       0.008903       0.062299
# 2379       0.571506       0.008288       0.053347
# 9074       0.572626       0.002101       0.055226
# 3050       0.561771       0.042386       0.014935
# 809        0.587687       0.031550       0.057828
# ...             ...            ...            ...
# 1028       0.030672       0.038421       0.115333
# 2572       0.336454       0.013813       0.117784
# 8276       0.343538       0.156431       0.251098
# 2201       0.210489       0.022779       0.313045
# 9918       0.368651       0.030259       0.196267
#
# [1000 rows x 8 columns]

# %%
plt.style.use('seaborn-dark')
portfolios.plot.scatter(x='Volatilidade', y='Retorno', c='Sharpe Ratio', edgecolors='black', figsize=(21,9), grid=True)
plt.xlabel('Volatilidade', fontsize=16)
plt.ylabel('Retorno Esperado', fontsize=16)
plt.title('Fronteira Eficiente de Markowitz', fontsize=22)
plt.savefig('Fronteira.png', dpi = 500)
